# %% [markdown]
# <a href="https://colab.research.google.com/github/fabiomiguell/AtividadesMackenzie/blob/main/M%C3%B3dulo_1_Trilha_1_Tarefa_Introdu%C3%A7%C3%A3o_%C3%A0_programa%C3%A7%C3%A3o_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Trilha 1: Tarefa**
#
# Implemente um programa em Python (Python notebook) que constrói um dicionário de termos de um documento (mínimo 1000 palavras) com a frequência de cada termo permitindo confirmar a lei de Zipf para o documento selecionado.
#
# Comente ao final os resultados obtidos.

# %% [markdown]
# # **Introdução**
#
# O texto utilizado para esta Tarefa foi o livro de **Salmos** da **Bíblia Sagrada** em formato .TXT. A ideia veio a partir da minha grande admiração pela Bíblia Sagrada e como uma forma de homenageá-la resolvi escolher o seu maior livro, o Salmos.

# %% [markdown]
# ### Bibliotécas Utilizadas

# %%
# Para o dataframe
import pandas as pd

# Para o gráfico
import matplotlib.pyplot as plt
import seaborn as sns

# Para stopwords
import nltk

# Para a imagem
from PIL import Image
import numpy as np

# Para a nuvem de palavras
from wordcloud import WordCloud

# %matplotlib inline

# %% [markdown]
# ### Extraindo e Limpando os Dados

# %%
texto = []

txt = open('/content/Salmos.txt', 'r')
for linha in txt:
  texto.append(linha)

sinais = ['\n', '.', ',', '(', ')', '?', '!', '\'', '[', ']', ';', ':']

for i in range(len(texto)):
  for j in sinais:
    texto[i] = texto[i].lower() # Mantendo o texto em letra minúscula
    texto[i] = texto[i].replace(j,'') # Retirando todos os sinais
    texto[i] = ''.join([i for i in texto[i] if not i.isdigit()]) # Retirando os dígitos

# %%
nltk.download() # Realizando o download do pacote stopwords
# Out:
# NLTK Downloader
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> d
#
# Download which package (l=list; x=cancel)?
#   Identifier> stopwords
#     Downloading package stopwords to /root/nltk_data...
#       Unzipping corpora/stopwords.zip.
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> q
# True

# %%
texto2 = ''.join(texto).split() # Unindo as frases e separando por palavras

stopwordsnltk = nltk.corpus.stopwords.words('portuguese') # Extraindo as Stopwords do NLTK
texto3 = [palavra for palavra in texto2 if palavra not in stopwordsnltk] # Retirando as Stopwords

print(texto3)
# Out:
# ['salmos', 'bem-aventurado', 'homem', 'anda', 'segundo', 'conselho', 'ímpios', 'detém', 'caminho', 'pecadores', 'assenta', 'roda', 'escarnecedores', 'antes', 'prazer', 'lei', 'senhor', 'lei', 'medita', 'dia', 'noite', 'pois', 'árvore', 'plantada', 'junto', 'correntes', 'águas', 'dá', 'fruto', 'estação', 'própria', 'cuja', 'folha', 'cai', 'tudo', 'quanto', 'fizer', 'prosperará', 'assim', 'ímpios', 'semelhantes', 'moinha', 'vento', 'espalha', 'ímpios', 'subsistirão', 'juízo', 'pecadores', 'congregação', 'justos', 'porque', 'senhor', 'conhece', 'caminho', 'justos', 'caminho', 'ímpios', 'conduz', 'ruína', 'salmos', 'amotinam', 'nações', 'povos', 'tramam', 'vão', 'reis', 'terra', 'levantam', 'príncipes', 'juntos', 'conspiram', 'contra', 'senhor', 'contra', 'ungido', 'dizendo', 'rompamos', 'ataduras', 'sacudamos', 'cordas', 'sentado', 'céus', 'rirá', 'senhor', 'zombará', 'então', 'falará', 'ira', 'furor', 'confundirá', 'dizendo', 'estabelecido', 'rei', 'sobre', 'sião', 'santo', 'monte', 'falarei', 'decreto', 'senhor', 'disse', 'és', 'filho', 'hoje', 'gerei', 'pede-me', 'darei', 'nações', 'herança', 'extremidades', 'terra', 'possessão', 'quebrarás', 'vara', 'ferro', 'despedaçarás', 'vaso', 'oleiro', 'agora', 'pois', 'ó', 'reis', 'sede', 'prudentes', 'deixai-vos', 'instruir', 'juízes', 'terra', 'servi', 'senhor', 'temor', 'regozijai-vos', 'tremor', 'beijai', 'filho', 'ire', 'pereçais', 'caminho', 'porque', 'breve', 'inflamará', 'ira', 'bem-aventurados', 'todos', 'nele', 'confiam', 'salmos', 'senhor', 'têm', 'multiplicado', 'adversários', 'muitos', 'levantam', 'contra', 'mim', 'muitos', 'dizem', 'mim', 'socorro', 'deus', 'senhor', 'és', 'escudo', 'redor', 'mim', 'glória', 'exulta', 'cabeça', 'voz', 'clamo', 'senhor', 'santo', 'monte', 'responde', 'deito', 'durmo', 'acordo', 'pois', 'senhor', 'sustenta', 'medo', 'dez', 'milhares', 'pessoas', 'puseram', 'contra', 'mim', 'redor', 'levanta-te', 'senhor', 'salva-me', 'deus', 'pois', 'feres', 'queixo', 'todos', 'inimigos', 'quebras', 'dentes', 'ímpios', 'salvação', 'vem', 'senhor', 'sobre', 'povo', 'bênção', 'salmos', 'responde-me', 'clamar', 'ó', 'deus', 'justiça', 'angústia', 'deste', 'largueza', 'misericórdia', 'mim', 'ouve', 'oração', 'filhos', 'homens', 'convertereis', 'glória', 'infâmia', 'amareis', 'vaidade', 'buscareis', 'mentira', 'sabei', 'senhor', 'separou', 'si', 'piedoso', 'senhor', 'ouve', 'clamo', 'irai-vos', 'pequeis', 'consultai', 'vosso', 'coração', 'vosso', 'leito', 'calai-vos', 'oferecei', 'sacrifícios', 'justiça', 'confiai', 'senhor', 'muitos', 'dizem', 'mostrará', 'bem', 'levanta', 'senhor', 'sobre', 'luz', 'rosto', 'puseste', 'coração', 'alegria', 'tempo', 'multiplicam', 'trigo', 'vinho', 'paz', 'deitarei', 'dormirei', 'porque', 'senhor', 'fazes', 'habitar', 'segurança', 'salmos', 'dá', 'ouvidos', 'palavras', 'ó', 'senhor', 'atende', 'gemidos', 'atende', 'voz', 'clamor', 'rei', 'deus', 'pois', 'ti', 'oro', 'manhã', 'ouves', 'voz', 'ó', 'senhor', 'manhã', 'apresento', 'oração', 'vigio', 'porque', 'és', 'deus', 'prazer', 'iniqüidade', 'contigo', 'habitará', 'mal', 'arrogantes', 'subsistirão', 'diante', 'olhos', 'detestas', 'todos', 'praticam', 'maldade', 'destróis', 'proferem', 'mentira', 'sanguinário', 'fraudulento', 'senhor', 'abomina', 'grandeza', 'benignidade', 'entrarei', 'casa', 'temor', 'inclinarei', 'santo', 'templo', 'guia-me', 'senhor', 'justiça', 'causa', 'inimigos', 'aplana', 'diante', 'mim', 'caminho', 'porque', 'fidelidade', 'boca', 'entranhas', 'verdadeiras', 'maldades', 'garganta', 'sepulcro', 'aberto', 'lisonjeiam', 'língua', 'declara-os', 'culpados', 'ó', 'deus', 'caiam', 'próprios', 'conselhos', 'lança-os', 'causa', 'multidão', 'transgressões', 'pois', 'revoltaram', 'contra', 'ti', 'alegrem-se', 'todos', 'confiam', 'ti', 'exultem', 'eternamente', 'porquanto', 'defendes', 'sim', 'gloriem-se', 'ti', 'amam', 'nome', 'pois', 'senhor', 'abençoas', 'justo', 'circundas', 'favor', 'escudo', 'salmos', 'senhor', 'repreendas', 'ira', 'castigues', 'furor', 'compai ...

# %% [markdown]
# ### Construindo o Dicionário

# %%
contaPalavra = {}

# Contando as palavras
for i in texto3:
  contaPalavra[i] = texto3.count(i)

print(contaPalavra)
# Out:
# {'salmos': 151, 'bem-aventurado': 17, 'homem': 66, 'anda': 8, 'segundo': 39, 'conselho': 10, 'ímpios': 57, 'detém': 1, 'caminho': 53, 'pecadores': 6, 'assenta': 2, 'roda': 2, 'escarnecedores': 1, 'antes': 20, 'prazer': 11, 'lei': 35, 'senhor': 794, 'medita': 1, 'dia': 67, 'noite': 30, 'pois': 217, 'árvore': 2, 'plantada': 1, 'junto': 9, 'correntes': 5, 'águas': 39, 'dá': 28, 'fruto': 11, 'estação': 1, 'própria': 6, 'cuja': 16, 'folha': 1, 'cai': 2, 'tudo': 24, 'quanto': 24, 'fizer': 4, 'prosperará': 1, 'assim': 48, 'semelhantes': 2, 'moinha': 2, 'vento': 17, 'espalha': 1, 'subsistirão': 2, 'juízo': 14, 'congregação': 9, 'justos': 26, 'porque': 164, 'conhece': 12, 'conduz': 3, 'ruína': 3, 'amotinam': 1, 'nações': 59, 'povos': 47, 'tramam': 1, 'vão': 10, 'reis': 24, 'terra': 191, 'levantam': 15, 'príncipes': 15, 'juntos': 7, 'conspiram': 2, 'contra': 107, 'ungido': 10, 'dizendo': 20, 'rompamos': 1, 'ataduras': 1, 'sacudamos': 1, 'cordas': 11, 'sentado': 2, 'céus': 56, 'rirá': 1, 'zombará': 1, 'então': 44, 'falará': 6, 'ira': 32, 'furor': 10, 'confundirá': 1, 'estabelecido': 3, 'rei': 43, 'sobre': 142, 'sião': 38, 'santo': 37, 'monte': 21, 'falarei': 4, 'decreto': 2, 'disse': 14, 'és': 59, 'filho': 13, 'hoje': 3, 'gerei': 1, 'pede-me': 1, 'darei': 10, 'herança': 27, 'extremidades': 7, 'possessão': 1, 'quebrarás': 1, 'vara': 3, 'ferro': 4, 'despedaçarás': 1, 'vaso': 2, 'oleiro': 1, 'agora': 17, 'ó': 251, 'sede': 8, 'prudentes': 1, 'deixai-vos': 1, 'instruir': 1, 'juízes': 4, 'servi': 2, 'temor': 12, 'regozijai-vos': 4, 'tremor': 3, 'beijai': 1, 'ire': 1, 'pereçais': 1, 'breve': 3, 'inflamará': 1, 'bem-aventurados': 6, 'todos': 158, 'nele': 22, 'confiam': 10, 'têm': 30, 'multiplicado': 1, 'adversários': 26, 'muitos': 13, 'mim': 193, 'dizem': 14, 'socorro': 12, 'deus': 439, 'escudo': 20, 'redor': 19, 'glória': 54, 'exulta': 1, 'cabeça': 21, 'voz': 48, 'clamo': 21, 'responde': 2, 'deito': 1, 'durmo': 2, 'acordo': 4, 'sustenta': 3, 'medo': 6, 'dez': 5, 'milhares': 7, 'pessoas': 2, 'puseram': 2, 'levanta-te': 10, 'salva-me': 12, 'feres': 1, 'queixo': 1, 'inimigos': 67, 'quebras': 1, 'dentes': 7, 'salvação': 60, 'vem': 18, 'povo': 82, 'bênção': 5, 'responde-me': 3, 'clamar': 3, 'justiça': 77, 'angústia': 26, 'deste': 8, 'largueza': 1, 'misericórdia': 12, 'ouve': 26, 'oração': 25, 'filhos': 68, 'homens': 61, 'convertereis': 1, 'infâmia': 1, 'amareis': 1, 'vaidade': 8, 'buscareis': 1, 'mentira': 3, 'sabei': 3, 'separou': 1, 'si': 9, 'piedoso': 4, 'irai-vos': 1, 'pequeis': 1, 'consultai': 1, 'vosso': 8, 'coração': 133, 'leito': 5, 'calai-vos': 1, 'oferecei': 1, 'sacrifícios': 10, 'confiai': 3, 'mostrará': 1, 'bem': 44, 'levanta': 7, 'luz': 23, 'rosto': 29, 'puseste': 8, 'alegria': 18, 'tempo': 20, 'multiplicam': 3, 'trigo': 7, 'vinho': 5, 'paz': 23, 'deitarei': 1, 'dormirei': 1, 'fazes': 16, 'habitar': 8, 'segurança': 7, 'ouvidos': 31, 'palavras': 30, 'atende': 7, 'gemidos': 1, 'clamor': 15, 'ti': 145, 'oro': 1, 'manhã': 17, 'ouves': 3, 'apresento': 1, 'vigio': 2, 'iniqüidade': 49, 'contigo': 6, 'habitará': 5, 'mal': 43, 'arrogantes': 5, 'diante': 60, 'olhos': 60, 'detestas': 1, 'praticam': 18, 'maldade': 8, 'destróis': 2, 'proferem': 2, 'sanguinário': 1, 'fraudulento': 2, 'abomina': 1, 'grandeza': 9, 'benignidade': 108, 'entrarei': 3, 'casa': 47, 'inclinarei': 2, 'templo': 11, 'guia-me': 7, 'causa': 56, 'aplana': 1, 'fidelidade': 29, 'boca': 65, 'entranhas': 5, 'verdadeiras': 2, 'maldades': 2, 'garganta': 4, 'sepulcro': 1, 'aberto': 1, 'lisonjeiam': 2, 'língua': 31, 'declara-os': 1, 'culpados': 1, 'caiam': 4, 'próprios': 6, 'conselhos': 2, 'lança-os': 1, 'multidão': 8, 'transgressões': 7, 'revoltaram': 1, 'alegrem-se': 7, 'exultem': 3, 'eternamente': 13, 'porquanto': 17, 'defendes': 1, 'sim': 38, 'gloriem-se': 1, 'amam': 8, 'nome': 109, 'abençoas': 1, 'justo': 30, 'circundas': 1, 'favor': 12, 'repreendas': 2, 'castigues': 2, 'compaixão': 11, 'fraco': 2, 'sara-me': 1, 'ossos': 16, 'perturbados': 3, 'alma': 85, 'perturbada': 1, 'volta-te':  ...

# %% [markdown]
# ### Visualização Gráfica

# %%
pd.set_option('display.max_rows', None) # Para visualizar todas as linhas do Dataframe
df = pd.DataFrame(list(contaPalavra.items()), columns=['Palavra', 'Quantidade']) # Criando um Dataframe
df = df.sort_values(by='Quantidade', ascending=False, ignore_index=True) # Ordenando de forma decrescente o Dataframe pela coluna Quantidade 
df = df[df['Quantidade']>26] # Filtrando a coluna Quantidade para valores maiores que 26
df.head(20)
# Out:
#         Palavra  Quantidade
# 0        senhor         794
# 1          deus         439
# 2             ó         251
# 3          pois         217
# 4           mim         193
# 5         terra         191
# 6        porque         164
# 7         todos         158
# 8        salmos         151
# 9            ti         145
# 10        sobre         142
# 11       sempre         135
# 12      coração         133
# 13         nome         109
# 14  benignidade         108
# 15       contra         107
# 16         alma          85
# 17         povo          82
# 18      justiça          77
# 19        todas          70

# %%
sns.set_theme(style='darkgrid') # Definindo a cor de fundo
plt.figure(figsize=(24,10)) # Definindo o tamanho do Dataframe
sns.barplot(x='Palavra', y='Quantidade', data=df, palette='ch:s=.25,rot=-.25') # Definindo os dados dos eixos x e y e a cor das barras
plt.xticks(rotation=90) # Alterando a posição dos nomes no gráfico
plt.show() # Plotando o gráfico

# %%
cristo = np.array(Image.open("/content/Cristo-Redentor.jpg")) # Extraindo a imagem

# Gerando uma wordcloud
wordcloud = WordCloud(background_color='Black', 
                      width=1000, height=1000, 
                      max_words=2000, mask=cristo, 
                      max_font_size=200,min_font_size=1
                      ).generate_from_frequencies(contaPalavra)
plt.subplots(figsize=(10,10))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.show()

# %% [markdown]
# # **Conclusão**
#
# Conclui-se que os cinco termos com maior frequência no livro de Salmos foram: *'senhor'*, *'deus'*, *'ó'*, *'pois'* e *'mim'*, onde se confirma a teoria da Lei de Zipf, que diz que a palavra mais frequente ocorrerá aproximadamente duas vezes mais frequentemente do que a segunda palavra mais frequente, três vezes mais vezes que a terceira palavra mais frequente, e assim sucessivamente.
